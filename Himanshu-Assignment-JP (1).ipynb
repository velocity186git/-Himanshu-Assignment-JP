# %% [markdown]
# <center>
#     <img src="https://scontent.fpnq7-6.fna.fbcdn.net/v/t39.30808-1/302253040_588160886091945_7460910077455209667_n.png?stp=dst-png_s200x200&_nc_cat=104&ccb=1-7&_nc_sid=2d3e12&_nc_ohc=nDDzHO01VGkQ7kNvwEUvN-H&_nc_oc=AdktnoNhWCQ04MsAFyzaV31yVRR16TNuVT2S7-r_dI3VPV88unGI1FVFkWkzW2UQri4&_nc_zt=24&_nc_ht=scontent.fpnq7-6.fna&_nc_gid=iiFT0pCkB9V2nS7osM9Z-g&oh=00_AfdTqIIZUm3cHE1j30jS6mU2zDgln4cXmmYAxR_0VTpVfA&oe=690B8A10" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Himanshu-Assignment-JP

# %% [markdown]
# ### Introduction to Python and Jupyter , this is a sample assignment created for coursera.

# %% [markdown]
# #### List of data science languages:
#
# - Python
# - R
# - SQL
# - Julia
# - Scala
# - Java
# - MATLAB
# - JavaScript

# %% [markdown]
# #### Popular Data Science Libraries:
#
# - PySpark
# - Statsmodels
# - Apache Airflow
# - PyTorch
# - Keras
# - TensorFlow
# - XGBoost
# - Scikit-learn
# - Plotly
# - Seaborn
# - Matplotlib
# - NumPy
# - Pandas

# %% [markdown]
# Table of popular **Data Science tools**, categorised by their primary function:
#
# | **Tool**            | **Category**              | **Primary Use**                                         | **Notable Features**                          |
# |---------------------|---------------------------|----------------------------------------------------------|------------------------------------------------|
# | **Jupyter Notebook**| IDE / Notebook             | Interactive coding, documentation, and visualization     | Supports Python, R, Julia; Markdown support   |
# | **RStudio**         | IDE                        | Statistical computing and graphics with R                | Integrated plotting, R Markdown               |
# | **Anaconda**        | Package Manager / Platform | Manages Python/R environments and packages               | Includes Jupyter, Spyder, Conda               |
# | **Spyder**          | IDE                        | Scientific Python development                            | MATLAB-like interface                         |
# | **VS Code**         | IDE                        | Lightweight code editor with extensions for data science | Git integration, Jupyter support              |
# | **Apache Spark**    | Big Data Framework         | Distributed data processing                              | Scalable, supports Python (PySpark)           |
# | **Tableau**         | Visualization              | Interactive dashboards and visual analytics              | Drag-and-drop interface, real-time updates    |
# | **Power BI**        | Visualization              | Business intelligence and reporting                      | Microsoft ecosystem integration               |
# | **Excel**           | Spreadsheet                | Data analysis and visualization                          | Pivot tables, formulas, charts                |
# | **Google Colab**    | Cloud Notebook             | Online Jupyter environment with free GPU access          | Collaboration, pre-installed libraries        |
# | **KNIME**           | Workflow Automation        | Visual programming for data workflows                    | No-code interface, integrates with Python/R   |
# | **RapidMiner**      | Workflow Automation        | Machine learning and data prep via GUI                   | Drag-and-drop modeling                        |
# | **Hadoop**          | Big Data Framework         | Distributed storage and processing                       | HDFS, MapReduce                               |
# | **GitHub**          | Version Control / Hosting  | Code collaboration and version tracking                  | Pull requests, CI/CD integration              |
# | **Docker**          | Containerization           | Packaging and deploying data science environments        | Reproducibility, scalability                  |
#
# Let me know if you’d like a version focused on open-source tools, cloud platforms, or beginner-friendly options!

# %% [markdown]
# #### Arithmetic expression examples
#
# x = 1
# y = 2
# z = x+y
#
# 1+1
# 1-2+3
# 2*3
# 4/5

# %%
# multiply and add numbers
2*2+1
# Out:
# 5

# %%
#convert minutes to hours

minutes = 180
hours = minutes / 60
print(hours)
# Out:
# 3.0

# %% [markdown]
# ### Objectives
#
# - Understand the purpose of Jupyter Notebooks in data science workflows
# - Practice using Markdown to create well-structured documentation
# - Demonstrate the ability to combine code and narrative text effectively

# %% [markdown]
# ## Author
#
# **Name:** Himanshu
