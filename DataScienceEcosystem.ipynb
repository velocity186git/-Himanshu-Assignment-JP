# %% [markdown]
# <center>
#     <img src="https://i.pinimg.com/originals/e6/c2/e2/e6c2e23b4c030c6b277a7bd68b7f885b.jpg" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### Introduction to Python and Jupyter, this is a sample assignment created for Coursera. In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# #### Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala
# 6. Java
# 7. MATLAB
# 8. JavaScript

# %% [markdown]
# #### Some of the commonly used libraries used by Data Scientists include:
#
# 1. PySpark
# 2. Statsmodels
# 3. Apache Airflow
# 4. PyTorch
# 5. Keras
# 6. TensorFlow
# 7. XGBoost
# 8. Scikit-learn|
# 9. Plotly
# 10. Seaborn
# 11. Matplotlib
# 12. NumPy
# 13. Pandas

# %% [markdown]
# #### Data Science Tools
#
# | **Tool**            | **Category**              | **Primary Use**                                         | **Notable Features**                          |
# |---------------------|---------------------------|----------------------------------------------------------|------------------------------------------------|
# | **Jupyter Notebook**| IDE / Notebook             | Interactive coding, documentation, and visualization     | Supports Python, R, Julia; Markdown support   |
# | **RStudio**         | IDE                        | Statistical computing and graphics with R                | Integrated plotting, R Markdown               |
# | **Anaconda**        | Package Manager / Platform | Manages Python/R environments and packages               | Includes Jupyter, Spyder, Conda               |
# | **Spyder**          | IDE                        | Scientific Python development                            | MATLAB-like interface                         |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
#
# x = 1
# y = 2
# z = x+y
#
# 1+1
# 1-2+3
# 2*3
# 4/5

# %%
# This a simple arithmetic expression to multiply and then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60

minutes = 200
hours = minutes / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ### Objectives
#
# - Understand the purpose of Jupyter Notebooks in data science workflows
# - Practice using Markdown to create well-structured documentation
# - Demonstrate the ability to combine code and narrative text effectively
# - List popular languages for Data Science

# %% [markdown]
# ## Author
#
# **Name:** Himanshu
